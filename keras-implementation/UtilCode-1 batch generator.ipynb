# %% [markdown]
# reference:
#
# https://github.com/martin-gorner/tensorflow-rnn-shakespeare/blob/master/my_txtutils.py
# https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py

# %%
import numpy as np

# %%
# size of the alphabet that we work with
ALPHASIZE = 98


# Specification of the supported alphabet (subset of ASCII-7)
# 10 line feed LF
# 32-64 numbers and punctuation
# 65-90 upper-case letters
# 91-97 more punctuation
# 97-122 lower-case letters
# 123-126 more punctuation
def convert_from_alphabet(a):
    """Encode a character
    :param a: one character
    :return: the encoded value
    """
    a = ord(a)
    if a == 9:
        return 1
    if a == 10:
        return 127 - 30  # LF
    elif 32 <= a <= 126:
        return a - 30
    else:
        return 0  # unknown


# encoded values:
# unknown = 0
# tab = 1
# space = 2
# all chars from 32 to 126 = c-30
# LF mapped to 127-30
def convert_to_alphabet(c, avoid_tab_and_lf=False):
    """Decode a code point
    :param c: code point
    :param avoid_tab_and_lf: if True, tab and line feed characters are replaced by '\'
    :return: decoded character
    """
    out_c = 0
    
    if c == 1:
        out_c = 32 if avoid_tab_and_lf else 9  # space instead of TAB
    if c == 127 - 30:
        out_c = 92 if avoid_tab_and_lf else 10  # \ instead of LF
    if 32 <= c + 30 <= 126:
        out_c = c + 30
    else:
        return '?'  # unknown
    return chr(out_c)

# %%
text='ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz'
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# ('corpus length:', 62)
# ('total chars:', 62)

# %%
def generate_batches(text, batch_size, sequence_size, num_of_chars, num_of_epochs):
    """
    Divides the data into batches of sequences so that all the sequences in one batch
    continue in the next batch. This is a generator that will keep returning batches
    until the input data has been seen nb_epochs times. Sequences are continued even
    between epochs, apart from one, the one corresponding to the end of raw_data.
    The remainder at the end of raw_data that does not fit in an full batch is ignored.
    :param raw_data: the training text
    :param batch_size: the size of a training minibatch
    :param sequence_size: the unroll size of the RNN
    :num_of_chars: the number of chars for encodering charactors
    :param num_of_epochs: number of epochs to train on
    :return:
        X_encode: one group of batches of training sequences, encoded
        Y_encode: one group of batches of training label sequences, encoded
        X: one group of batches of training sequences, not encoded, used for debugging
        Y: one group of batches of training label sequences, not encoded, used for debugging
        epoch: the current epoch number (starting at 0)
    """
    
    data = np.array(list(text))
    data_len = data.shape[0]

    num_of_batchs = (data_len - 1) // (batch_size * sequence_size) # len(sentences) = num_of_batch * batch_size

    assert num_of_batchs > 0, "Not enough data, even for a single batch. Try using a smaller batch_size."

    rounded_data_len = num_of_batchs * batch_size * sequence_size

    xdata = np.reshape(data[0:rounded_data_len], [batch_size, num_of_batchs * sequence_size])
    ydata = np.reshape(data[1:rounded_data_len + 1], [batch_size, num_of_batchs * sequence_size])
    

    for epoch in range(num_of_epochs):
        start = True
        for batch in range(num_of_batchs):
            x = xdata[:, batch * sequence_size:(batch + 1) * sequence_size]
            y = ydata[:, batch * sequence_size:(batch + 1) * sequence_size]
            x = np.roll(x, -epoch, axis=0)  # to continue the text from epoch to epoch (do not reset rnn state!)
            y = np.roll(y, -epoch, axis=0)
            
            if start:
                 X = x
                 Y = y[:, -1]
            else:
                X = np.vstack((X, x))
                Y = np.hstack((Y, y[:, -1]))
            start = False
        
        X_encode = np.zeros((num_of_batchs * batch_size, sequence_size, num_of_chars), dtype=np.bool)
        Y_encode = np.zeros((num_of_batchs * batch_size, num_of_chars), dtype=np.bool)
        for i, sentence in enumerate(X):
            for t, char in enumerate(sentence):
                X_encode[i, t, convert_from_alphabet(char)] = 1
        
        for i, char in enumerate(Y):
            Y_encode[i, convert_from_alphabet(char)] = 1
            
        yield X_encode, Y_encode, X, Y, epoch

# %% [markdown]
# ## Test generate_batches() function

# %%
seq_len = 7
batch_size=4

ge = generate_batches(text, batch_size, seq_len, ALPHASIZE, 10)

# %%
X_encode, Y_encode, X,Y, epoch = ge.next()
print('Epoch number {}'.format(epoch))
print('X_encode.shape', X_encode.shape)
print('Y_encode.shape', Y_encode.shape)
print('X.shape', X.shape)
print('Y.shape', Y.shape)
print(X)
print(Y)

X_decode = []
for i, sentence in enumerate(X_encode):
    line = []
    for t, char_code in enumerate(sentence):
        line.append(convert_to_alphabet(np.argmax(char_code)))
    X_decode.append(line)             
print(np.array(X_decode))

Y_decode = []
for i, char_code in enumerate(Y_encode):
    Y_decode.append(convert_to_alphabet(np.argmax(char_code)))                
print(np.array(Y_decode))
# Out:
# Epoch number 0
# ('X_encode.shape', (8, 7, 98))
# ('Y_encode.shape', (8, 98))
# ('X.shape', (8, 7))
# ('Y.shape', (8,))
# [['A' 'B' 'C' 'D' 'E' 'F' 'G']
#  ['O' 'P' 'Q' 'R' 'S' 'T' 'U']
#  ['3' '4' '5' '6' '7' '8' '9']
#  ['g' 'h' 'i' 'j' 'k' 'l' 'm']
#  ['H' 'I' 'J' 'K' 'L' 'M' 'N']
#  ['V' 'W' 'X' 'Y' 'Z' '1' '2']
#  ['0' 'a' 'b' 'c' 'd' 'e' 'f']
#  ['n' 'o' 'p' 'q' 'r' 's' 't']]
# ['H' 'V' '0' 'n' 'O' '3' 'g' 'u']
# [['A' 'B' 'C' 'D' 'E' 'F' 'G']
#  ['O' 'P' 'Q' 'R' 'S' 'T' 'U']
#  ['3' '4' '5' '6' '7' '8' '9']
#  ['g' 'h' 'i' 'j' 'k' 'l' 'm']
#  ['H' 'I' 'J' 'K' 'L' 'M' 'N']
#  ['V' 'W' 'X' 'Y' 'Z' '1' '2']
#  ['0' 'a' 'b' 'c' 'd' 'e' 'f']
#  ['n' 'o' 'p' 'q' 'r' 's' 't']]
# ['H' 'V' '0' 'n' 'O' '3' 'g' 'u']

# %%
X_encode, Y_encode, X,Y, epoch = ge.next()
print epoch
print X_encode.shape
print X.shape
print Y.shape
print X
print Y

X_decode = []
for i, sentence in enumerate(X_encode):
    line = []
    for t, char_code in enumerate(sentence):
        line.append(convert_to_alphabet(np.argmax(char_code)))
    X_decode.append(line)             
print(np.array(X_decode))

Y_decode = []
for i, char_code in enumerate(Y_encode):
    Y_decode.append(convert_to_alphabet(np.argmax(char_code)))                
print(np.array(Y_decode))
# Out:
# 1
# (8, 7, 98)
# (8, 7)
# (8,)
# [['O' 'P' 'Q' 'R' 'S' 'T' 'U']
#  ['3' '4' '5' '6' '7' '8' '9']
#  ['g' 'h' 'i' 'j' 'k' 'l' 'm']
#  ['A' 'B' 'C' 'D' 'E' 'F' 'G']
#  ['V' 'W' 'X' 'Y' 'Z' '1' '2']
#  ['0' 'a' 'b' 'c' 'd' 'e' 'f']
#  ['n' 'o' 'p' 'q' 'r' 's' 't']
#  ['H' 'I' 'J' 'K' 'L' 'M' 'N']]
# ['V' '0' 'n' 'H' '3' 'g' 'u' 'O']
# [['O' 'P' 'Q' 'R' 'S' 'T' 'U']
#  ['3' '4' '5' '6' '7' '8' '9']
#  ['g' 'h' 'i' 'j' 'k' 'l' 'm']
#  ['A' 'B' 'C' 'D' 'E' 'F' 'G']
#  ['V' 'W' 'X' 'Y' 'Z' '1' '2']
#  ['0' 'a' 'b' 'c' 'd' 'e' 'f']
#  ['n' 'o' 'p' 'q' 'r' 's' 't']
#  ['H' 'I' 'J' 'K' 'L' 'M' 'N']]
# ['V' '0' 'n' 'H' '3' 'g' 'u' 'O']

# %%
epoch
# Out:
# 1

# %% [markdown]
# ## Data prepare process in a Kera code example
# https://github.com/fchollet/keras/blob/master/examples/lstm_text_generation.py
#
# We will not using it as we would like to use a stateful LSTM model and we would like our batchsize to be large

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 6
step = 2
batch_size=4
num_epochs = 10

sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# ('nb sequences:', 28)
# Vectorization...

# %%
print(sentences[0])
print(sentences[3])

print(sentences[2])
print(sentences[5])
# Out:
# ABCDEF
# GHIJKL
# EFGHIJ
# KLMNOP

# %%
len(sentences)
# Out:
# 28

# %%
print X.shape
print y.shape
# Out:
# (28, 6, 62)
# (28, 62)

# %% [markdown]
# # Build a very simple model and test our batch generator code:

# %%
from __future__ import print_function
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys

# size of the alphabet that we work with
ALPHASIZE = 98

text='ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz' \
    + 'ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyz'

num_of_epochs = 400
sequence_size = 5
batch_size = 10
num_of_chars = ALPHASIZE

# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(256, batch_input_shape=(batch_size, sequence_size, num_of_chars), stateful = True))
model.add(Dense(num_of_chars))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer) 
# adam optimizer will not work, at least not that fast...? why?
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
batch_generator = generate_batches(text, batch_size, sequence_size, num_of_chars, num_of_epochs)

# train the model, output generated text after each iteration
for iteration in range(1, num_of_epochs):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    
    X,y, _X, _y, epoch = batch_generator.next()
    
    model.fit(X, y,
              batch_size=batch_size,
              epochs=1,
              shuffle=False
              )

    start_index = random.randint(0, len(text) - sequence_size - 1)
    
    if (iteration + 1)  % 10 == 0:
        for diversity in [0.1]:
            print()
            print('----- diversity:', diversity)

            generated = ''
            sentence = '_ABCD' #text[start_index: start_index + sequence_size]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            sys.stdout.write(generated)
            
            model.reset_states()
            
            for i in range(100):
                x = np.zeros((batch_size, sequence_size, num_of_chars))
                for i, batch in enumerate(x):
                    for t, char in enumerate(sentence):
                        x[i, t, convert_from_alphabet(char)] = 1.

                preds = model.predict(x, verbose=0)
                preds = preds[0]
                next_index = sample(preds, diversity)
                next_char = convert_to_alphabet(next_index)

                generated += next_char
                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
            
            generated_2 = ''
            sentence_2 = 'x#,3F' #text[start_index: start_index + sequence_size]
            generated_2 += sentence_2
            print('\n----- Generating with seed: "' + sentence_2 + '"')
            sys.stdout.write(generated_2)
            
            model.reset_states()
            
            for i in range(100):
                x = np.zeros((batch_size, sequence_size, num_of_chars))
                for i, batch in enumerate(x):
                    for t, char in enumerate(sentence_2):
                        x[i, t, convert_from_alphabet(char)] = 1.

                preds = model.predict(x, verbose=0)
                preds = preds[0]
                next_index = sample(preds, diversity)
                next_char = convert_to_alphabet(next_index)

                generated_2 += next_char
                sentence_2 = sentence_2[1:] + next_char

                sys.stdout.write(next_char)
            print()
# Out:
# --------------------------------------------------
# Iteration 1
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.9769
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.2451
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.6307
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.0665
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.6383
#
# --------------------------------------------------
# Iteration 6
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3310
#
# --------------------------------------------------
# Iteration 7
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.8087
#
# --------------------------------------------------
# Iteration 8
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.0736
#
# --------------------------------------------------
# Iteration 9
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.7920
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEJKPXZ5achijkmquzBFKPS56aefhhjmosyBGKPU16afghsjkowyBGHPXZ5abcdefhhopowABGKPX567efghijopyBHLRW289himd
# ----- Generating with seed: "x#,3F"
# x#,3FD0aefhijopyBHLQW27efhityopuADINSX39cdfghimuwAEJKLPQRWXefhhojkswBDHIN9399cdfghimuzDEFGHNOTY40afghijop
#
# --------------------------------------------------
# Iteration 10
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.4184
#
# --------------------------------------------------
# Iteration 11
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.2853
#
# --------------------------------------------------
# Iteration 12
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0297
#
# --------------------------------------------------
# Iteration 13
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0110
#
# --------------------------------------------------
# Iteration 14
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0038
#
# --------------------------------------------------
# Iteration 15
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0020
#
# --------------------------------------------------
# Iteration 16
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0011
#
# --------------------------------------------------
# Iteration 17
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.8950e-04
#
# --------------------------------------------------
# Iteration 18
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.1745e-04
#
# --------------------------------------------------
# Iteration 19
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7111e-04
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEJOTY49diBdfqriSX389MQVW6yEJOTY49dinowBJKPTY49deAcGjIkOVX38ccGLPQqZ5DJOPUZ50ejopFCHMRW27bglqyzEJOTY4
# ----- Generating with seed: "x#,3F"
# x#,3F5INSX38chmcdpqzEFKOTY450N9cdfghijopurUBGMQSX38chpqzpuzEJOTY49dindfnrxCHMRW27bglq7zEJOTY49dinoxCHLQV1
#
# --------------------------------------------------
# Iteration 20
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7484
#
# --------------------------------------------------
# Iteration 21
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0627
#
# --------------------------------------------------
# Iteration 22
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0078
#
# --------------------------------------------------
# Iteration 23
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0022
#
# --------------------------------------------------
# Iteration 24
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0013
#
# --------------------------------------------------
# Iteration 25
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.0556e-04
#
# --------------------------------------------------
# Iteration 26
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.8879e-04
#
# --------------------------------------------------
# Iteration 27
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.9321e-04
#
# --------------------------------------------------
# Iteration 28
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7355e-04
#
# --------------------------------------------------
# Iteration 29
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.0195e-04
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEJOPfghuqrx0efbhmno98efajouqrx8ceafgijop0eflumnfgopypf8ejkpqw9dfdhjopu8cdefkpumopw8Qeahins50eglqw8bh
# ----- Generating with seed: "x#,3F"
# x#,3FDf5cimsF0afbhjkpqrpZhmv8chirw9cdjntz0afdsjkpqw9Mfghmnspy0fnsijk0dejpumqw8LeSThiq50dbghmnw90ekpu6bcef
#
# --------------------------------------------------
# Iteration 30
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.6216
#
# --------------------------------------------------
# Iteration 31
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0031
#
# --------------------------------------------------
# Iteration 32
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0011
#
# --------------------------------------------------
# Iteration 33
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.5355e-04
#
# --------------------------------------------------
# Iteration 34
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.0177e-04
#
# --------------------------------------------------
# Iteration 35
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.4962e-04
#
# --------------------------------------------------
# Iteration 36
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5316e-04
#
# --------------------------------------------------
# Iteration 37
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 9.2967e-05
#
# --------------------------------------------------
# Iteration 38
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.6238e-05
#
# --------------------------------------------------
# Iteration 39
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.3919e-05
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEJKPOTUVX3456789qrsjklqnspuvwxopqrsuy9nsjrw49nfgsqkmrw8qhirw8qvAnfgsw98bgkqqwtywAcoUVrwxyDErwxJNST44
# ----- Generating with seed: "x#,3F"
# x#,3FGHMRPQRSX3456acdqrsklulqnspuz0nspulmnswxJKLQRSTY4567bfkpuopuKDLPUu760fkpulqnswxysjoty9sgkqvmotpqvurw
#
# --------------------------------------------------
# Iteration 40
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.3783
#
# --------------------------------------------------
# Iteration 41
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0016
#
# --------------------------------------------------
# Iteration 42
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.5733e-04
#
# --------------------------------------------------
# Iteration 43
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.9867e-04
#
# --------------------------------------------------
# Iteration 44
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.9489e-04
#
# --------------------------------------------------
# Iteration 45
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2654e-04
#
# --------------------------------------------------
# Iteration 46
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.1709e-05
#
# --------------------------------------------------
# Iteration 47
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.2374e-05
#
# --------------------------------------------------
# Iteration 48
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.3210e-05
#
# --------------------------------------------------
# Iteration 49
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.0678e-05
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFLMNPQSTUVWX34567bcdjkgiqrs7GjkprkoqrsEhinstcejklmprsu7wBDFKMNPQSTUVWX34567bcdjkgiqrs7GjkprNoqrDEpu
# ----- Generating with seed: "x#,3F"
# x#,3FGIJOLMRSUX3890achihjkqrsDFGLPORSTU334567bcijkqpqrsuDEFLNOPRSTUVX345678cdjkqkqrwCEGLMOPQRSTZ3789cijij
#
# --------------------------------------------------
# Iteration 50
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.1543
#
# --------------------------------------------------
# Iteration 51
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.6414e-04
#
# --------------------------------------------------
# Iteration 52
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2758e-04
#
# --------------------------------------------------
# Iteration 53
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.7899e-05
#
# --------------------------------------------------
# Iteration 54
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.0001e-05
#
# --------------------------------------------------
# Iteration 55
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.0519e-05
#
# --------------------------------------------------
# Iteration 56
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.7051e-05
#
# --------------------------------------------------
# Iteration 57
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7915e-05
#
# --------------------------------------------------
# Iteration 58
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1798e-05
#
# --------------------------------------------------
# Iteration 59
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.6972e-06
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNST378ceklnopqr456acefklmnrRVZ567c9jklmnopxX167DJFGLMNO36babdefklmnvpX345678djklmnrsxyHnZHJ
# ----- Generating with seed: "x#,3F"
# x#,3FGINOPQV280bdefklmqQUZ379acdefklmqQUX34578cehjklmnoREF56a790ejbhmnofqrsABHJJKPQWX34567bdeejkl67oKghij
#
# --------------------------------------------------
# Iteration 60
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0060
#
# --------------------------------------------------
# Iteration 61
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5385e-05
#
# --------------------------------------------------
# Iteration 62
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 9.4962e-06
#
# --------------------------------------------------
# Iteration 63
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.2103e-06
#
# --------------------------------------------------
# Iteration 64
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.1149e-06
#
# --------------------------------------------------
# Iteration 65
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.7321e-06
#
# --------------------------------------------------
# Iteration 66
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.8142e-06
#
# --------------------------------------------------
# Iteration 67
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1894e-06
#
# --------------------------------------------------
# Iteration 68
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.8028e-07
#
# --------------------------------------------------
# Iteration 69
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.9038e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGLMNOQRSTUZ1834567890abcdijklqrstuvwxyzABCDEFGHINOPUSTY4567b9deklmnopqrsBCEFGHIJKLMNOQUV2345678cde
# ----- Generating with seed: "x#,3F"
# x#,3FGLMNO890acdefghijklmnopqrsABDEFGHINOPQST467890abcdijklqrstuvwxyzABCDEFGHINOPUSTY4567b9deZ1j7k1L34567
#
# --------------------------------------------------
# Iteration 70
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.2396
#
# --------------------------------------------------
# Iteration 71
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1512e-04
#
# --------------------------------------------------
# Iteration 72
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.8815e-05
#
# --------------------------------------------------
# Iteration 73
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.5548e-05
#
# --------------------------------------------------
# Iteration 74
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.2602e-05
#
# --------------------------------------------------
# Iteration 75
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4593e-05
#
# --------------------------------------------------
# Iteration 76
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 9.4737e-06
#
# --------------------------------------------------
# Iteration 77
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.1687e-06
#
# --------------------------------------------------
# Iteration 78
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.9968e-06
#
# --------------------------------------------------
# Iteration 79
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.5798e-06
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGNOQUVXYZ1234567890abcdefghijklmnopqrCEEFGMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrCEEFGMNOPQRSTU
# ----- Generating with seed: "x#,3F"
# x#,3FGLOTUVWX34567890abcdefghijklmnopqrCEEFGMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrCEEFGMNOPQRSTUVWXYZ
#
# --------------------------------------------------
# Iteration 80
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.1716
#
# --------------------------------------------------
# Iteration 81
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.6148e-05
#
# --------------------------------------------------
# Iteration 82
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7820e-05
#
# --------------------------------------------------
# Iteration 83
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3561e-05
#
# --------------------------------------------------
# Iteration 84
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.0364e-05
#
# --------------------------------------------------
# Iteration 85
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.8387e-06
#
# --------------------------------------------------
# Iteration 86
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.7931e-06
#
# --------------------------------------------------
# Iteration 87
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.1729e-06
#
# --------------------------------------------------
# Iteration 88
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.9152e-06
#
# --------------------------------------------------
# Iteration 89
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.9583e-06
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGLMNOPQRSTUVWXYZ567890abcdefgklmnopqrsBMRSTUVWXYZ567890abcdefgklmnopqrsBNRSTUVWXYZ1234567klmnopurs
# ----- Generating with seed: "x#,3F"
# x#,3FGLMNOPQRSTUVWXYZ54QRSBUVFGLMNOPQRSXYZ567890abcdefgklmnopqrsBMRSCUVWXLMNRSTUVWXYZ1234567890abcdefjklm
#
# --------------------------------------------------
# Iteration 90
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.1081
#
# --------------------------------------------------
# Iteration 91
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.6489e-05
#
# --------------------------------------------------
# Iteration 92
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.0808e-05
#
# --------------------------------------------------
# Iteration 93
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.6335e-05
#
# --------------------------------------------------
# Iteration 94
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2329e-05
#
# --------------------------------------------------
# Iteration 95
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.8616e-06
#
# --------------------------------------------------
# Iteration 96
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.0908e-06
#
# --------------------------------------------------
# Iteration 97
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.0207e-06
#
# --------------------------------------------------
# Iteration 98
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.5874e-06
#
# --------------------------------------------------
# Iteration 99
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.6559e-06
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqnopqrsEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqnopq
# ----- Generating with seed: "x#,3F"
# x#,3F5Wu890abcdefghijklqnopqrsEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqnopqrsEFGHIJKLMNOPQRSTUVWXYZ12
#
# --------------------------------------------------
# Iteration 100
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0025
#
# --------------------------------------------------
# Iteration 101
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.0504e-06
#
# --------------------------------------------------
# Iteration 102
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4511e-06
#
# --------------------------------------------------
# Iteration 103
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.0247e-06
#
# --------------------------------------------------
# Iteration 104
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.1580e-07
#
# --------------------------------------------------
# Iteration 105
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.9201e-07
#
# --------------------------------------------------
# Iteration 106
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.3541e-07
#
# --------------------------------------------------
# Iteration 107
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.4113e-07
#
# --------------------------------------------------
# Iteration 108
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.8261e-07
#
# --------------------------------------------------
# Iteration 109
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4901e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefg
# ----- Generating with seed: "x#,3F"
# x#,3F5qrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ12
#
# --------------------------------------------------
# Iteration 110
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0203
#
# --------------------------------------------------
# Iteration 111
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2214e-06
#
# --------------------------------------------------
# Iteration 112
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.5806e-07
#
# --------------------------------------------------
# Iteration 113
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.3807e-07
#
# --------------------------------------------------
# Iteration 114
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.9285e-07
#
# --------------------------------------------------
# Iteration 115
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.9911e-07
#
# --------------------------------------------------
# Iteration 116
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3408e-07
#
# --------------------------------------------------
# Iteration 117
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7990e-07
#
# --------------------------------------------------
# Iteration 118
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5768e-07
#
# --------------------------------------------------
# Iteration 119
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3601e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOSTUVWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOSTUVWXYZ1234567890abcdefghijklm
# ----- Generating with seed: "x#,3F"
# x#,3F567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOSTUVWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGHIJK
#
# --------------------------------------------------
# Iteration 120
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0088
#
# --------------------------------------------------
# Iteration 121
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3463e-06
#
# --------------------------------------------------
# Iteration 122
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5367e-06
#
# --------------------------------------------------
# Iteration 123
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.0675e-06
#
# --------------------------------------------------
# Iteration 124
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.5156e-07
#
# --------------------------------------------------
# Iteration 125
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.4078e-07
#
# --------------------------------------------------
# Iteration 126
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.9827e-07
#
# --------------------------------------------------
# Iteration 127
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.9748e-07
#
# --------------------------------------------------
# Iteration 128
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3246e-07
#
# --------------------------------------------------
# Iteration 129
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.8748e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOrrUVCCEFGHIJKLMNOrrrrCFEFGHIJKLMNOrrUVCCEFGHIJKLMNOrrrUVCXEFGHIJKLMNOrrUrCCCEFGHIJKLMNOrr
# ----- Generating with seed: "x#,3F"
# x#,3F567890abcdefghijklmnopqrwtBCDEFGHIJKLMNOrrUVCCCEFGHIJKLMNOrrUrUUVXXZ1234567890abcdefghijklmnopqrwtBC
#
# --------------------------------------------------
# Iteration 130
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0840
#
# --------------------------------------------------
# Iteration 131
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.8360e-06
#
# --------------------------------------------------
# Iteration 132
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.4214e-06
#
# --------------------------------------------------
# Iteration 133
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.2005e-06
#
# --------------------------------------------------
# Iteration 134
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4522e-06
#
# --------------------------------------------------
# Iteration 135
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 9.7373e-07
#
# --------------------------------------------------
# Iteration 136
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.6161e-07
#
# --------------------------------------------------
# Iteration 137
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.6383e-07
#
# --------------------------------------------------
# Iteration 138
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.2945e-07
#
# --------------------------------------------------
# Iteration 139
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.4384e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOrrUVVXZZ1234567890abddijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRUVWXZZ1234567890abddfghijklmnop
# ----- Generating with seed: "x#,3F"
# x#,3F5678sjklmnopqrstuwxyzABCDEFGHIJKLMNOPQRUVXYZ1234567890abddfghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRUVXY
#
# --------------------------------------------------
# Iteration 140
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.1133
#
# --------------------------------------------------
# Iteration 141
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.6194e-06
#
# --------------------------------------------------
# Iteration 142
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.2257e-06
#
# --------------------------------------------------
# Iteration 143
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3089e-06
#
# --------------------------------------------------
# Iteration 144
# Epoch 1/1
# 110/110 [==============================] - ETA: 0s - loss: 1.5842e-0 - 0s - loss: 1.6646e-06
#
# --------------------------------------------------
# Iteration 145
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2024e-06
#
# --------------------------------------------------
# Iteration 146
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.6590e-07
#
# --------------------------------------------------
# Iteration 147
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.1664e-07
#
# --------------------------------------------------
# Iteration 148
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.4053e-07
#
# --------------------------------------------------
# Iteration 149
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.2728e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFKLMNOPQRSTUVWXYZ1234567890abddfghijklmnopqrstwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddfghijklmn
# ----- Generating with seed: "x#,3F"
# x#,3F567890abddfghijklmnopqrstwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddfghijklmnopqrstwxyzABCDEFGHIJKL
#
# --------------------------------------------------
# Iteration 150
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0650
#
# --------------------------------------------------
# Iteration 151
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.6843e-06
#
# --------------------------------------------------
# Iteration 152
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.7920e-06
#
# --------------------------------------------------
# Iteration 153
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.6692e-06
#
# --------------------------------------------------
# Iteration 154
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.9415e-06
#
# --------------------------------------------------
# Iteration 155
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4321e-06
#
# --------------------------------------------------
# Iteration 156
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.0501e-06
#
# --------------------------------------------------
# Iteration 157
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.6240e-07
#
# --------------------------------------------------
# Iteration 158
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.4132e-07
#
# --------------------------------------------------
# Iteration 159
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.8526e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefgh
# ----- Generating with seed: "x#,3F"
# x#,3F567890abddefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abdefghijklmnopqrstuwxyzABCDEFGHI
#
# --------------------------------------------------
# Iteration 160
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.0801e-04
#
# --------------------------------------------------
# Iteration 161
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.8068e-07
#
# --------------------------------------------------
# Iteration 162
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.1241e-07
#
# --------------------------------------------------
# Iteration 163
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7394e-07
#
# --------------------------------------------------
# Iteration 164
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5226e-07
#
# --------------------------------------------------
# Iteration 165
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3763e-07
#
# --------------------------------------------------
# Iteration 166
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2625e-07
#
# --------------------------------------------------
# Iteration 167
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2138e-07
#
# --------------------------------------------------
# Iteration 168
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 169
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddef
# ----- Generating with seed: "x#,3F"
# x#,3F567890abddfghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddefghijklmnopqrstuvwxyzABCDEFG
#
# --------------------------------------------------
# Iteration 170
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0748
#
# --------------------------------------------------
# Iteration 171
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1325e-06
#
# --------------------------------------------------
# Iteration 172
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.3881e-07
#
# --------------------------------------------------
# Iteration 173
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.2856e-07
#
# --------------------------------------------------
# Iteration 174
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.7305e-07
#
# --------------------------------------------------
# Iteration 175
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.5167e-07
#
# --------------------------------------------------
# Iteration 176
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.6009e-07
#
# --------------------------------------------------
# Iteration 177
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.9940e-07
#
# --------------------------------------------------
# Iteration 178
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.6364e-07
#
# --------------------------------------------------
# Iteration 179
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4359e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddfghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddfgh
# ----- Generating with seed: "x#,3F"
# x#,3F567890abddfghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddfghijklmnopqrstuvwxyzABCDEFGH
#
# --------------------------------------------------
# Iteration 180
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0058
#
# --------------------------------------------------
# Iteration 181
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2371e-06
#
# --------------------------------------------------
# Iteration 182
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 9.4230e-07
#
# --------------------------------------------------
# Iteration 183
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 7.2826e-07
#
# --------------------------------------------------
# Iteration 184
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.5866e-07
#
# --------------------------------------------------
# Iteration 185
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.2482e-07
#
# --------------------------------------------------
# Iteration 186
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.2512e-07
#
# --------------------------------------------------
# Iteration 187
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.5251e-07
#
# --------------------------------------------------
# Iteration 188
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.0049e-07
#
# --------------------------------------------------
# Iteration 189
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.6906e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdef
# ----- Generating with seed: "x#,3F"
# x#,3F5HIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefgh
#
# --------------------------------------------------
# Iteration 190
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0014
#
# --------------------------------------------------
# Iteration 191
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.8108e-07
#
# --------------------------------------------------
# Iteration 192
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.7852e-07
#
# --------------------------------------------------
# Iteration 193
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.2054e-07
#
# --------------------------------------------------
# Iteration 194
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.8044e-07
#
# --------------------------------------------------
# Iteration 195
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5551e-07
#
# --------------------------------------------------
# Iteration 196
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3872e-07
#
# --------------------------------------------------
# Iteration 197
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2950e-07
#
# --------------------------------------------------
# Iteration 198
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2192e-07
#
# --------------------------------------------------
# Iteration 199
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2138e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSXYZ1234567890abcdefghijklqnopqrstuvwxyzABCDEFGHIJKLMNOPQRSXYZ1234567890abcdefghijklqn
# ----- Generating with seed: "x#,3F"
# x#,3F567890abcdefghijklqnopqrstuvwxyzABCDEFGHIJKLMNOPQRSXYZ1234567890abcdefghijklqnopqrstuvwxyzABCDEFGHIJ
#
# --------------------------------------------------
# Iteration 200
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.9309e-04
#
# --------------------------------------------------
# Iteration 201
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.0970e-07
#
# --------------------------------------------------
# Iteration 202
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5714e-07
#
# --------------------------------------------------
# Iteration 203
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3547e-07
#
# --------------------------------------------------
# Iteration 204
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2625e-07
#
# --------------------------------------------------
# Iteration 205
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2138e-07
#
# --------------------------------------------------
# Iteration 206
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2029e-07
#
# --------------------------------------------------
# Iteration 207
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 208
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 209
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefg
# ----- Generating with seed: "x#,3F"
# x#,3F567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGH
#
# --------------------------------------------------
# Iteration 210
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.7309e-06
#
# --------------------------------------------------
# Iteration 211
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 212
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 213
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 214
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 215
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 216
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 217
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 218
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 219
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqnstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqn
# ----- Generating with seed: "x#,3F"
# x#,3F567890abcdefghijklmrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrswyzABCDEFGHIJKLMN
#
# --------------------------------------------------
# Iteration 220
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0052
#
# --------------------------------------------------
# Iteration 221
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.9630e-07
#
# --------------------------------------------------
# Iteration 222
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 4.4324e-07
#
# --------------------------------------------------
# Iteration 223
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.0832e-07
#
# --------------------------------------------------
# Iteration 224
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3408e-07
#
# --------------------------------------------------
# Iteration 225
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.8477e-07
#
# --------------------------------------------------
# Iteration 226
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5985e-07
#
# --------------------------------------------------
# Iteration 227
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4251e-07
#
# --------------------------------------------------
# Iteration 228
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3113e-07
#
# --------------------------------------------------
# Iteration 229
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2571e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdef
# ----- Generating with seed: "x#,3F"
# x#,3F5UIXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuv
#
# --------------------------------------------------
# Iteration 230
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4310e-05
#
# --------------------------------------------------
# Iteration 231
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7448e-07
#
# --------------------------------------------------
# Iteration 232
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2409e-07
#
# --------------------------------------------------
# Iteration 233
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2029e-07
#
# --------------------------------------------------
# Iteration 234
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 235
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 236
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 237
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 238
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 239
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqnotqvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghij
# ----- Generating with seed: "x#,3F"
# x#,3F57890abcdefghijklqnstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqnotqvwxyzABCDEFGHIJKLMNO
#
# --------------------------------------------------
# Iteration 240
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.7137e-07
#
# --------------------------------------------------
# Iteration 241
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 242
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 243
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 244
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 245
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 246
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 247
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 248
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 249
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijk
# ----- Generating with seed: "x#,3F"
# x#,3F5V7890abcdefghijklqrstuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklqrstuwxyzABCDEFGHIJKLMNOP
#
# --------------------------------------------------
# Iteration 250
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0275
#
# --------------------------------------------------
# Iteration 251
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4977e-06
#
# --------------------------------------------------
# Iteration 252
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 8.3501e-07
#
# --------------------------------------------------
# Iteration 253
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 6.2368e-07
#
# --------------------------------------------------
# Iteration 254
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.0068e-07
#
# --------------------------------------------------
# Iteration 255
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.9610e-07
#
# --------------------------------------------------
# Iteration 256
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.1807e-07
#
# --------------------------------------------------
# Iteration 257
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.5467e-07
#
# --------------------------------------------------
# Iteration 258
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.0537e-07
#
# --------------------------------------------------
# Iteration 259
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.7502e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrswyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghij
# ----- Generating with seed: "x#,3F"
# x#,3F57890abcdefghijklmnopqrwwyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrswyzABCDEFGHIJKLMNO
#
# --------------------------------------------------
# Iteration 260
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3287e-05
#
# --------------------------------------------------
# Iteration 261
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3709e-07
#
# --------------------------------------------------
# Iteration 262
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2571e-07
#
# --------------------------------------------------
# Iteration 263
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2246e-07
#
# --------------------------------------------------
# Iteration 264
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2138e-07
#
# --------------------------------------------------
# Iteration 265
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 266
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 267
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 268
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 269
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abdeffghijklmnstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abdeffghij
# ----- Generating with seed: "x#,3F"
# x#,3FklmnopqrsuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abdeffghijklmnstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1
#
# --------------------------------------------------
# Iteration 270
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 271
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 272
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 273
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 274
# Epoch 1/1
# ...
#
# --------------------------------------------------
# Iteration 310
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5768e-07
#
# --------------------------------------------------
# Iteration 311
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 312
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07     - ETA: 0s - loss: 1.1921e-0
#
# --------------------------------------------------
# Iteration 313
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 314
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 315
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 316
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 317
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 318
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 319
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ527490dbfghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ527490dbfghijklmnopqrst
# ----- Generating with seed: "x#,3F"
# x#,3Fk7890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ527490dbfghijklmnopqrstuvwxyzABCDEFGHIJKLMN
#
# --------------------------------------------------
# Iteration 320
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3330e-07
#
# --------------------------------------------------
# Iteration 321
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 322
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 323
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 324
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 325
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 326
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 327
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 328
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 329
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdef
# ----- Generating with seed: "x#,3F"
# x#,3Fk7ukJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdefg
#
# --------------------------------------------------
# Iteration 330
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.3738e-04
#
# --------------------------------------------------
# Iteration 331
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.6581e-07
#
# --------------------------------------------------
# Iteration 332
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4251e-07
#
# --------------------------------------------------
# Iteration 333
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3059e-07
#
# --------------------------------------------------
# Iteration 334
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2300e-07
#
# --------------------------------------------------
# Iteration 335
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2083e-07
#
# --------------------------------------------------
# Iteration 336
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 337
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 338
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 339
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWX3Z1234567890abcdefghijklmnopqrsuvwxyzABCHEFGHIJKLMNOPQRSTUVWX3Z1234567890abcdijk
# ----- Generating with seed: "x#,3F"
# x#,3FGHIJKLMNOPQRSTUVWX3Z1234567890abcdijklmnopqrwxyzABCDEFGHIJKLMNOPQRSTUVWX3Z1234567890abcdefghijklmnop
#
# --------------------------------------------------
# Iteration 340
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 5.5866e-07
#
# --------------------------------------------------
# Iteration 341
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 342
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 343
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 344
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 345
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 346
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 347
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 348
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 349
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWX3Z12345678efghijklmnopqrwwyzABCDEFGHIJKLMNOPQRSTUVWX3Z12345678eghijklmnopqrwwyzA
# ----- Generating with seed: "x#,3F"
# x#,3FGHIJKLMNOPQRSTUV7XkZ7890dijklmnopqrsuvwxyzABCDEFGHIJKLMNOPQRSTUV7X9ZabgdijklmnopqrwwyzABCDEFGHIJKLMN
#
# --------------------------------------------------
# Iteration 350
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 351
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 352
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 353
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 354
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 355
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 356
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 357
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 358
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 359
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUV7X9ZabgdijklmnopqrwwyzABCDEFGHIJKLMNOPQRSTUVWX3Z12345678ehhijklmnopqrwwyzABCDEFGHI
# ----- Generating with seed: "x#,3F"
# x#,3FGHIJKLMNOPQRSTUV7XkZKLMNOPQRSTUVWXYZ1234567890abcdijklmnopqrwxyzABCDEFGHIJKLMNOPQRSTUV7X9Zabgdijklmn
#
# --------------------------------------------------
# Iteration 360
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.5497e-07
#
# --------------------------------------------------
# Iteration 361
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 362
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 363
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 364
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 365
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 366
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 367
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 368
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 369
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddefgiijklmnopqrwtyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddefgiij
# ----- Generating with seed: "x#,3F"
# x#,3FCHIJKLMNOPQRSTUVWXYZ1234567890abcdefghijklmnopqrwtyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddijklmnop
#
# --------------------------------------------------
# Iteration 370
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 371
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 372
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 373
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 374
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 375
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 376
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 377
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 378
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 379
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdijklmnopqrwtyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abcdijklmnopqr
# ----- Generating with seed: "x#,3F"
# x#,3F577890hijklmnopqrsFuwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890abddijklmnopqrwtyvABCDEFGHIJKLMNOPQRSTUV
#
# --------------------------------------------------
# Iteration 380
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2036e-05
#
# --------------------------------------------------
# Iteration 381
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2354e-07
#
# --------------------------------------------------
# Iteration 382
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 383
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 384
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 385
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 386
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 387
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 388
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# --------------------------------------------------
# Iteration 389
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.1921e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRWXYZ1234567890abcdefghijklmno
# ----- Generating with seed: "x#,3F"
# x#,3FklmnopursywxyzABCDEFGHIJKLMNOPQRWXYZ1234567890abcdefghijklmnopqrstuwxyzABCDEFGHIJKLMNOPQRWXYZ1234567
#
# --------------------------------------------------
# Iteration 390
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 0.0330
#
# --------------------------------------------------
# Iteration 391
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 3.4950e-07
#
# --------------------------------------------------
# Iteration 392
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.8448e-07
#
# --------------------------------------------------
# Iteration 393
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 2.3192e-07
#
# --------------------------------------------------
# Iteration 394
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.9670e-07
#
# --------------------------------------------------
# Iteration 395
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.6798e-07
#
# --------------------------------------------------
# Iteration 396
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.4847e-07
#
# --------------------------------------------------
# Iteration 397
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.3601e-07
#
# --------------------------------------------------
# Iteration 398
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2842e-07
#
# --------------------------------------------------
# Iteration 399
# Epoch 1/1
# 110/110 [==============================] - 0s - loss: 1.2463e-07
#
# ----- diversity: 0.1
# ----- Generating with seed: "_ABCD"
# _ABCDEFGHIJKLMNOPQRWXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRWXYZ1234567890abcdefghijklmn
# ----- Generating with seed: "x#,3F"
# x#,3F5HIJKLMNOPQRWXYZ1234567890abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRWXYZ1234567890abcdefghijklmnop
